# %%
#Mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/Deep_Learning/Homeworks/HW7/DLStudio-2.0.8')

# %%
# !sudo python3 setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing DLStudio.egg-info/PKG-INFO
# writing dependency_links to DLStudio.egg-info/dependency_links.txt
# writing top-level names to DLStudio.egg-info/top_level.txt
# reading manifest file 'DLStudio.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# ...
# writing manifest file 'DLStudio.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/DLStudio
# copying build/lib/DLStudio/__init__.py -> build/bdist.linux-x86_64/egg/DLStudio
# copying build/lib/DLStudio/DLStudio.py -> build/bdist.linux-x86_64/egg/DLStudio
# creating build/bdist.linux-x86_64/egg/AdversarialNetworks
# copying build/lib/AdversarialNetworks/__init__.py -> build/bdist.linux-x86_64/egg/AdversarialNetworks
# ...

# %%
os.chdir('/content/drive/My Drive/Deep_Learning/Homeworks/HW7/DLStudio-2.0.8/Examples')

# %%
# !pip install pymsgbox
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-cp37-none-any.whl size=7420 sha256=b92ad7abc35184d5a035917d92e0dd2e73b0291d6652e25d5838d011f37ccefb
#   Stored in directory: /root/.cache/pip/wheels/16/d7/4e/fffdd54b1cca86608b7655c9a2854890a38f955ce9532848cd
# Successfully built pymsgbox
# ...

# %%
# !python3 text_classification_with_TEXTnet.py
# Out:
# The number of layers in the model: 6
#
# The number of learnable parameters in the model: 10718770
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 17001
#
#
#
# [epoch:1  iter: 500  elapsed_time:   65 secs]     loss: 0.69320
# [epoch:1  iter:1000  elapsed_time:  126 secs]     loss: 0.69262
# [epoch:1  iter:1500  elapsed_time:  190 secs]     loss: 0.69408
#
# [epoch:2  iter: 500  elapsed_time:  260 secs]     loss: 0.69291
# [epoch:2  iter:1000  elapsed_time:  327 secs]     loss: 0.69359
# [epoch:2  iter:1500  elapsed_time:  393 secs]     loss: 0.69294
#
# [epoch:3  iter: 500  elapsed_time:  468 secs]     loss: 0.69217
# [epoch:3  iter:1000  elapsed_time:  536 secs]     loss: 0.69370
# [epoch:3  iter:1500  elapsed_time:  598 secs]     loss: 0.69311
#
# [epoch:4  iter: 500  elapsed_time:  672 secs]     loss: 0.69286
# [epoch:4  iter:1000  elapsed_time:  733 secs]     loss: 0.69253
# [epoch:4  iter:1500  elapsed_time:  800 secs]     loss: 0.69274
#
# ...

# %% [markdown]
# ##Task 1##

# %%
# !python3 text_classification_with_TEXTnet_binary_encoding.py
# Out:
# The number of layers in the model: 6
#
# The number of learnable parameters in the model: 323950
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 17001
#
#
#
# [epoch:1  iter: 500  elapsed_time:   73 secs]     loss: 0.69380
# [epoch:1  iter:1000  elapsed_time:  139 secs]     loss: 0.69676
# [epoch:1  iter:1500  elapsed_time:  214 secs]     loss: 0.69409
#
# [epoch:2  iter: 500  elapsed_time:  299 secs]     loss: 0.69479
# [epoch:2  iter:1000  elapsed_time:  377 secs]     loss: 0.69288
# [epoch:2  iter:1500  elapsed_time:  439 secs]     loss: 0.69028
#
# [epoch:3  iter: 500  elapsed_time:  522 secs]     loss: 0.69144
# [epoch:3  iter:1000  elapsed_time:  589 secs]     loss: 0.69222
# [epoch:3  iter:1500  elapsed_time:  667 secs]     loss: 0.69004
#
# [epoch:4  iter: 500  elapsed_time:  747 secs]     loss: 0.68999
# [epoch:4  iter:1000  elapsed_time:  819 secs]     loss: 0.69104
# [epoch:4  iter:1500  elapsed_time:  890 secs]     loss: 0.68822
#
# ...

# %% [markdown]
# ##Task 3##

# %% [markdown]
# Batching on TextNet OneHot

# %%
# !python3 text_classification_with_TEXTnet.py
# Out:
# The number of layers in the model: 6
#
# The number of learnable parameters in the model: 2396182
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 3402
#
#
#
#
#
#
#
#
#
#
#
#
#
# Finished Training
#
# No handles with labels found to put in legend.
# <Figure size 1000x500 with 1 Axes>
#
# Overall classification accuracy: 55.10%
#
#
# Number of positive reviews tested: 25
#
#
# Number of negative reviews tested: 25
#
#
# Displaying the confusion matrix:
#
#                       predicted negative    predicted positive
#
# true negative:                 8.0              92.0
# true positive:                 0.0             100.0

# %%
# !python3 text_classification_with_TEXTnet_batching.py
# Out:
# The number of layers in the model: 6
#
# The number of learnable parameters in the model: 2396182
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 3402
#
#
#
# [epoch:1  iter:  20  elapsed_time:   30 secs]     loss: 0.69298
#
# [epoch:2  iter:  20  elapsed_time:   62 secs]     loss: 0.69315
#
# [epoch:3  iter:  20  elapsed_time:   93 secs]     loss: 0.69318
#
# [epoch:4  iter:  20  elapsed_time:  124 secs]     loss: 0.69319
#
# [epoch:5  iter:  20  elapsed_time:  156 secs]     loss: 0.69317
#
# [epoch:6  iter:  20  elapsed_time:  187 secs]     loss: 0.69310
#
# [epoch:7  iter:  20  elapsed_time:  218 secs]     loss: 0.69343
#
# [epoch:8  iter:  20  elapsed_time:  249 secs]     loss: 0.69328
#
# [epoch:9  iter:  20  elapsed_time:  280 secs]     loss: 0.69330
#
# [epoch:10  iter:  20  elapsed_time:  311 secs]     loss: 0.69319
#
# Finished Training
#
# No handles with labels found to put in legend.
# <Figure size 1000x500 with 1 Axes>
#
# ...

# %%
# !python3 text_classification_with_TEXTnet_batching_mean_review.py
# Out:
# The number of layers in the model: 6
#
# The number of learnable parameters in the model: 2396182
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 3402
#
#
#
# [epoch:1  iter:  20  elapsed_time:    5 secs]     loss: 0.69324
#
# [epoch:2  iter:  20  elapsed_time:   10 secs]     loss: 0.69312
#
# [epoch:3  iter:  20  elapsed_time:   15 secs]     loss: 0.69323
#
# [epoch:4  iter:  20  elapsed_time:   20 secs]     loss: 0.69307
#
# [epoch:5  iter:  20  elapsed_time:   26 secs]     loss: 0.69320
#
# [epoch:6  iter:  20  elapsed_time:   31 secs]     loss: 0.69302
#
# [epoch:7  iter:  20  elapsed_time:   36 secs]     loss: 0.69326
#
# [epoch:8  iter:  20  elapsed_time:   41 secs]     loss: 0.69328
#
# [epoch:9  iter:  20  elapsed_time:   47 secs]     loss: 0.69316
#
# [epoch:10  iter:  20  elapsed_time:   52 secs]     loss: 0.69307
#
# Finished Training
#
# No handles with labels found to put in legend.
# <Figure size 1000x500 with 1 Axes>
#
# ...

# %% [markdown]
# Batching on TextNetOrder2 OneHot

# %%
# !python3 text_classification_with_TEXTnetOrder2.py
# Out:
# The number of layers in the model: 8
#
# The number of learnable parameters in the model: 2972182
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 3402
#
#
#
#
#
#
#
#
#
#
#
#
#
# Finished Training
#
# No handles with labels found to put in legend.
# <Figure size 1000x500 with 1 Axes>
#
# Overall classification accuracy: 40.82%
#
#
# Number of positive reviews tested: 25
#
#
# Number of negative reviews tested: 25
#
#
# Displaying the confusion matrix:
#
#                       predicted negative    predicted positive
#
# true negative:                 4.0              96.0
# true positive:                24.0              76.0

# %%
# !python3 text_classification_with_TEXTnetOrder2_max_length_batching.py
# Out:
# The number of layers in the model: 8
#
# The number of learnable parameters in the model: 2972182
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 3402
#
#
#
# [epoch:1  iter:  20  elapsed_time:   39 secs]     loss: 0.69471
#
# [epoch:2  iter:  20  elapsed_time:   78 secs]     loss: 0.69390
#
# [epoch:3  iter:  20  elapsed_time:  117 secs]     loss: 0.69383
#
# [epoch:4  iter:  20  elapsed_time:  157 secs]     loss: 0.69314
#
# [epoch:5  iter:  20  elapsed_time:  196 secs]     loss: 0.69134
#
# [epoch:6  iter:  20  elapsed_time:  235 secs]     loss: 0.69424
#
# [epoch:7  iter:  20  elapsed_time:  275 secs]     loss: 0.69289
#
# [epoch:8  iter:  20  elapsed_time:  314 secs]     loss: 0.69204
#
# [epoch:9  iter:  20  elapsed_time:  353 secs]     loss: 0.69171
#
# [epoch:10  iter:  20  elapsed_time:  393 secs]     loss: 0.69186
#
# Finished Training
#
# No handles with labels found to put in legend.
# <Figure size 1000x500 with 1 Axes>
#
# ...

# %%
# !python3 text_classification_with_TEXTnetOrder2_mean_length_batching.py
# Out:
# The number of layers in the model: 8
#
# The number of learnable parameters in the model: 2972182
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 3402
#
#
#
# [epoch:1  iter:  20  elapsed_time:    6 secs]     loss: 0.69250
#
# [epoch:2  iter:  20  elapsed_time:   13 secs]     loss: 0.69474
#
# [epoch:3  iter:  20  elapsed_time:   20 secs]     loss: 0.69189
#
# [epoch:4  iter:  20  elapsed_time:   28 secs]     loss: 0.69473
#
# [epoch:5  iter:  20  elapsed_time:   35 secs]     loss: 0.69595
#
# [epoch:6  iter:  20  elapsed_time:   42 secs]     loss: 0.69428
#
# [epoch:7  iter:  20  elapsed_time:   49 secs]     loss: 0.69321
#
# [epoch:8  iter:  20  elapsed_time:   56 secs]     loss: 0.69304
#
# [epoch:9  iter:  20  elapsed_time:   63 secs]     loss: 0.69412
#
# [epoch:10  iter:  20  elapsed_time:   70 secs]     loss: 0.69596
#
# Finished Training
#
# No handles with labels found to put in legend.
# <Figure size 1000x500 with 1 Axes>
#
# ...

# %% [markdown]
# Batching on TextNetOrder2 Binary Encoding

# %%
# !python3 text_classification_with_TEXTnetOrder2_binary_encoding.py
# Out:
# The number of layers in the model: 8
#
# The number of learnable parameters in the model: 899950
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 3402
#
#
#
#
#
#
#
#
#
#
#
#
#
# Finished Training
#
# No handles with labels found to put in legend.
# <Figure size 1000x500 with 1 Axes>
#
# Overall classification accuracy: 57.14%
#
#
# Number of positive reviews tested: 25
#
#
# Number of negative reviews tested: 25
#
#
# Displaying the confusion matrix:
#
#                       predicted negative    predicted positive
#
# true negative:                36.0              64.0
# true positive:                24.0              76.0

# %%
# !python3 text_classification_with_TEXTnetOrder2_max_length_batching_with_binary_encoding.py
# Out:
# The number of layers in the model: 8
#
# The number of learnable parameters in the model: 899950
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 3402
#
#
#
# [epoch:1  iter:  20  elapsed_time:   29 secs]     loss: 0.69557
#
# [epoch:2  iter:  20  elapsed_time:   60 secs]     loss: 0.69707
#
# [epoch:3  iter:  20  elapsed_time:   90 secs]     loss: 0.69504
#
# [epoch:4  iter:  20  elapsed_time:  121 secs]     loss: 0.69395
#
# [epoch:5  iter:  20  elapsed_time:  151 secs]     loss: 0.69297
#
# [epoch:6  iter:  20  elapsed_time:  181 secs]     loss: 0.69543
#
# [epoch:7  iter:  20  elapsed_time:  212 secs]     loss: 0.69512
#
# [epoch:8  iter:  20  elapsed_time:  242 secs]     loss: 0.69247
#
# [epoch:9  iter:  20  elapsed_time:  272 secs]     loss: 0.69589
#
# [epoch:10  iter:  20  elapsed_time:  302 secs]     loss: 0.69280
#
# Finished Training
#
# No handles with labels found to put in legend.
# <Figure size 1000x500 with 1 Axes>
#
# ...

# %%
# !python3 text_classification_with_TEXTnetOrder2_mean_length_batching_with_binary_encoding.py
# Out:
# The number of layers in the model: 8
#
# The number of learnable parameters in the model: 899950
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 3402
#
#
#
# [epoch:1  iter:  20  elapsed_time:    5 secs]     loss: 0.69585
#
# [epoch:2  iter:  20  elapsed_time:   11 secs]     loss: 0.69185
#
# [epoch:3  iter:  20  elapsed_time:   16 secs]     loss: 0.69371
#
# [epoch:4  iter:  20  elapsed_time:   22 secs]     loss: 0.69225
#
# [epoch:5  iter:  20  elapsed_time:   27 secs]     loss: 0.69320
#
# [epoch:6  iter:  20  elapsed_time:   33 secs]     loss: 0.69017
#
# [epoch:7  iter:  20  elapsed_time:   39 secs]     loss: 0.69578
#
# [epoch:8  iter:  20  elapsed_time:   44 secs]     loss: 0.69327
#
# [epoch:9  iter:  20  elapsed_time:   50 secs]     loss: 0.69056
#
# [epoch:10  iter:  20  elapsed_time:   55 secs]     loss: 0.69374
#
# Finished Training
#
# No handles with labels found to put in legend.
# <Figure size 1000x500 with 1 Axes>
#
# ...

# %% [markdown]
# ##Task2##

# %%
#lr=1e-5
# !python3 text_classification_with_TEXTnetOrder2.py
# Out:
# The number of layers in the model: 8
#
# The number of learnable parameters in the model: 11294770
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 17001
#
#
#
# [epoch:1  iter: 500  elapsed_time:   76 secs]     loss: 0.69494
# [epoch:1  iter:1000  elapsed_time:  144 secs]     loss: 0.69363
# [epoch:1  iter:1500  elapsed_time:  213 secs]     loss: 0.69356
#
# [epoch:2  iter: 500  elapsed_time:  297 secs]     loss: 0.69336
# [epoch:2  iter:1000  elapsed_time:  368 secs]     loss: 0.69370
# [epoch:2  iter:1500  elapsed_time:  438 secs]     loss: 0.69395
#
# [epoch:3  iter: 500  elapsed_time:  516 secs]     loss: 0.69340
# [epoch:3  iter:1000  elapsed_time:  590 secs]     loss: 0.69386
# [epoch:3  iter:1500  elapsed_time:  665 secs]     loss: 0.69259
#
# [epoch:4  iter: 500  elapsed_time:  744 secs]     loss: 0.69361
# [epoch:4  iter:1000  elapsed_time:  816 secs]     loss: 0.69396
# [epoch:4  iter:1500  elapsed_time:  891 secs]     loss: 0.69363
#
# ...

# %%
#lr=1e-5
# !python3 classification_with_TEXTnetOrder2_double_gating.py
# Out:
# The number of layers in the model: 8
#
# The number of learnable parameters in the model: 11608114
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 17001
#
#
#
# [epoch:1  iter: 500  elapsed_time:   71 secs]     loss: 0.69149
# [epoch:1  iter:1000  elapsed_time:  147 secs]     loss: 0.69540
# [epoch:1  iter:1500  elapsed_time:  232 secs]     loss: 0.69375
#
# [epoch:2  iter: 500  elapsed_time:  316 secs]     loss: 0.69362
# [epoch:2  iter:1000  elapsed_time:  397 secs]     loss: 0.69365
# [epoch:2  iter:1500  elapsed_time:  472 secs]     loss: 0.69318
#
# [epoch:3  iter: 500  elapsed_time:  560 secs]     loss: 0.69224
# [epoch:3  iter:1000  elapsed_time:  641 secs]     loss: 0.69528
# [epoch:3  iter:1500  elapsed_time:  718 secs]     loss: 0.69404
#
# [epoch:4  iter: 500  elapsed_time:  804 secs]     loss: 0.69305
# [epoch:4  iter:1000  elapsed_time:  883 secs]     loss: 0.69240
# [epoch:4  iter:1500  elapsed_time:  963 secs]     loss: 0.69462
#
# ...

# %%
#lr=1e-5
# !python3 text_classification_with_GRU_binary_encoding.py
# Out:
# The number of layers in the model: 10
#
# The number of learnable parameters in the model: 2391042
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 17001
#
#
#
# [epoch:1  iter: 500  elapsed_time:  97 secs]     loss: 0.69436
# [epoch:1  iter:1000  elapsed_time: 192 secs]     loss: 0.69275
# [epoch:1  iter:1500  elapsed_time: 294 secs]     loss: 0.69360
#
# [epoch:2  iter: 500  elapsed_time: 401 secs]     loss: 0.69360
# [epoch:2  iter:1000  elapsed_time: 509 secs]     loss: 0.69347
# [epoch:2  iter:1500  elapsed_time: 609 secs]     loss: 0.69336
#
# [epoch:3  iter: 500  elapsed_time: 718 secs]     loss: 0.69405
# [epoch:3  iter:1000  elapsed_time: 817 secs]     loss: 0.69179
# [epoch:3  iter:1500  elapsed_time: 918 secs]     loss: 0.69366
#
# [epoch:4  iter: 500  elapsed_time:1032 secs]     loss: 0.69345
# [epoch:4  iter:1000  elapsed_time:1130 secs]     loss: 0.69337
# [epoch:4  iter:1500  elapsed_time:1228 secs]     loss: 0.69262
#
# ...

# %%
#lr=1e-5
# !python3 text_classification_with_GRU.py
# Out:
# The number of layers in the model: 10
#
# The number of learnable parameters in the model: 28480002
#
# The size of the vocabulary (which is also the size of the one-hot vecs for words): 17001
#
#
#
# [epoch:1  iter: 500  elapsed_time: 423 secs]     loss: 0.69286
# [epoch:1  iter:1000  elapsed_time: 835 secs]     loss: 0.69516
# [epoch:1  iter:1500  elapsed_time:1193 secs]     loss: 0.69272
#
# [epoch:2  iter: 500  elapsed_time:1641 secs]     loss: 0.69482
# [epoch:2  iter:1000  elapsed_time:2056 secs]     loss: 0.69317
# [epoch:2  iter:1500  elapsed_time:2477 secs]     loss: 0.69208
#
# [epoch:3  iter: 500  elapsed_time:2927 secs]     loss: 0.69537
# [epoch:3  iter:1000  elapsed_time:3338 secs]     loss: 0.69225
# [epoch:3  iter:1500  elapsed_time:3723 secs]     loss: 0.69320
#
# [epoch:4  iter: 500  elapsed_time:4191 secs]     loss: 0.69390
# [epoch:4  iter:1000  elapsed_time:4600 secs]     loss: 0.69298
# [epoch:4  iter:1500  elapsed_time:5006 secs]     loss: 0.69230
#
# ...
